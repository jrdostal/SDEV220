# %%
import pandas as pd

# %% [markdown]
# 1. CREATE

# %% [markdown]
# 1.1 Create from a CSV

# %%
df = pd.read_csv('telco_churn.csv')

# %% [markdown]
# 1.2 Create from a Dictionary

# %%
tempdict = {'col1':[1,2,3], 'col2':[4,5,6], 'col3':[7,8,9]}

# %%
dictdf = pd.DataFrame.from_dict(tempdict)

# %% [markdown]
# 2. READ

# %% [markdown]
# 2.1 Show Top 5 and Bottom 5 Rows

# %%
df.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1            110.0
# 1                     26              161.6            123.0
# 2                      0              243.4            114.0
# 3                      0              299.4             71.0
# 4                      0              166.7            113.0
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4             99.0             16.78
# 1             27.47              195.5            103.0             16.62
# 2             41.38              121.2            110.0             10.30
# 3             50.90               61.9             88.0              5.26
# 4             28.34              148.3            122.0             12.61
#
#    Total night minutes  Total night calls  Total night charge  \
# 0                244.7               91.0               11.01
# 1                254.4              103.0               11.45
# 2                162.6              104.0                7.32
# 3                196.9               89.0                8.86
# 4                186.9              121.0                8.41
#
#    Total intl minutes  Total intl calls  Total intl charge  \
# 0                10.0                 3               2.70
# 1                13.7                 3               3.70
# 2                12.2                 5               3.29
# 3                 6.6                 7               1.78
# 4                10.1                 3               2.73
#
#    Customer service calls  Churn
# 0                     1.0  False
# 1                     1.0  False
# 2                     0.0  False
# 3                     2.0  False
# 4                     3.0  False

# %%
df.head(10)
# Out:
#    State  Account length  Area code International plan Voice mail plan  \
# 0     KS             128        415                 No             Yes
# 1     OH             107        415                 No             Yes
# 2     NJ             137        415                 No              No
# 3     OH              84        408                Yes              No
# 4     OK              75        415                Yes              No
# 5     AL             118        510                Yes              No
# 7     MO             147        415                Yes              No
# 8     LA             117        408                 No              No
# 9     WV             141        415                Yes             Yes
# 10    IN              65        415                 No              No
#
#     Number vmail messages  Total day minutes  Total day calls  \
# 0                      25              265.1            110.0
# 1                      26              161.6            123.0
# 2                       0              243.4            114.0
# 3                       0              299.4             71.0
# 4                       0              166.7            113.0
# 5                       0              223.4             98.0
# 7                       0              157.0             79.0
# 8                       0              184.5             97.0
# 9                      37              258.6             84.0
# 10                      0              129.1            137.0
#
#     Total day charge  Total eve minutes  ...  Total night minutes  \
# 0              45.07              197.4  ...                244.7
# 1              27.47              195.5  ...                254.4
# 2              41.38              121.2  ...                162.6
# 3              50.90               61.9  ...                196.9
# 4              28.34              148.3  ...                186.9
# 5              37.98              220.6  ...                203.9
# 7              26.69              103.1  ...                211.8
# 8              31.37              351.6  ...                215.8
# 9              43.96              222.0  ...                326.4
# 10             21.95              228.5  ...                208.8
#
#     Total night calls  Total night charge  Total intl minutes  \
# 0                91.0               11.01                10.0
# 1               103.0               11.45                13.7
# 2               104.0                7.32                12.2
# 3                89.0                8.86                 6.6
# 4               121.0                8.41                10.1
# 5               118.0                9.18                 6.3
# 7                96.0                9.53                 7.1
# 8                90.0                9.71                 8.7
# 9                97.0               14.69                11.2
# 10              111.0                9.40                12.7
#
#     Total intl calls  Total intl charge  Customer service calls  Churn  \
# 0                  3               2.70                     1.0  False
# 1                  3               3.70                     1.0  False
# 2                  5               3.29                     0.0  False
# 3                  7               1.78                     2.0  False
# 4                  3               2.73                     3.0  False
# 5                  6               1.70                     0.0  False
# 7                  6               1.92                     0.0  False
# 8                  4               2.35                     1.0  False
# 9                  5               3.02                     0.0  False
# 10                 6               3.43                     4.0   True
#
#     New Column Churn Binary
# 0           10            0
# 1          100            0
# 2          100            0
# 3          100            0
# 4          100            0
# 5          100            0
# 7          100            0
# 8          100            0
# 9          100            0
# 10         100            1
#
# [10 rows x 22 columns]

# %%
dictdf.head()
# Out:
#    col1  col2  col3
# 0     1     4     7
# 1     2     5     8
# 2     3     6     9

# %%
df.tail()
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 3328                     36              156.2             77.0
# 3329                      0              231.1             57.0
# 3330                      0              180.8            109.0
# 3331                      0              213.8            105.0
# 3332                     25              234.4            113.0
#
#       Total day charge  Total eve minutes  ...  Total night minutes  \
# 3328             26.55              215.5  ...                279.1
# 3329             39.29              153.4  ...                191.3
# 3330             30.74              288.8  ...                191.9
# 3331             36.35              159.6  ...                139.2
# 3332             39.85              265.9  ...                241.4
#
#       Total night calls  Total night charge  Total intl minutes  \
# 3328               83.0               12.56                 9.9
# 3329              123.0                8.61                 9.6
# 3330               91.0                8.64                14.1
# 3331              137.0                6.26                 5.0
# 3332               77.0               10.86                13.7
#
#       Total intl calls  Total intl charge  Customer service calls  Churn  \
# 3328                 6               2.67                     2.0  False
# 3329                 4               2.59                     3.0  False
# 3330                 6               3.81                     2.0  False
# 3331                10               1.35                     2.0  False
# 3332                 4               3.70                     0.0  False
#
#       New Column Churn Binary
# 3328         100            0
# 3329         100            0
# 3330         100            0
# 3331         100            0
# 3332         100            0
#
# [5 rows x 22 columns]

# %%
df.tail(15)
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 3318    OK              52        415                 No              No
# 3319    WY              89        415                 No              No
# 3320    GA             122        510                Yes              No
# 3321    VT              60        415                 No              No
# 3322    MD              62        408                 No              No
# 3323    IN             117        415                 No              No
# 3324    WV             159        415                 No              No
# 3325    OH              78        408                 No              No
# 3326    OH              96        415                 No              No
# 3327    SC              79        415                 No              No
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 3318                      0              124.9            131.0
# 3319                      0              115.4             99.0
# 3320                      0              140.0            101.0
# 3321                      0              193.9            118.0
# 3322                      0              321.1            105.0
# 3323                      0              118.4            126.0
# 3324                      0              169.8            114.0
# 3325                      0              193.4             99.0
# 3326                      0              106.6            128.0
# 3327                      0              134.7             98.0
# 3328                     36              156.2             77.0
# 3329                      0              231.1             57.0
# 3330                      0              180.8            109.0
# 3331                      0              213.8            105.0
# 3332                     25              234.4            113.0
#
#       Total day charge  Total eve minutes  ...  Total night minutes  \
# 3318             21.23              300.5  ...                192.5
# 3319             19.62              209.9  ...                280.9
# 3320             23.80              196.4  ...                120.1
# 3321             32.96               85.0  ...                210.1
# 3322             54.59              265.5  ...                180.5
# 3323             20.13              249.3  ...                227.0
# 3324             28.87              197.7  ...                193.7
# 3325             32.88              116.9  ...                243.3
# 3326             18.12              284.8  ...                178.9
# 3327             22.90              189.7  ...                221.4
# 3328             26.55              215.5  ...                279.1
# 3329             39.29              153.4  ...                191.3
# 3330             30.74              288.8  ...                191.9
# 3331             36.35              159.6  ...                139.2
# 3332             39.85              265.9  ...                241.4
#
#       Total night calls  Total night charge  Total intl minutes  \
# 3318              106.0                8.66                11.6
# 3319              112.0               12.64                15.9
# 3320              133.0                5.40                 9.7
# 3321              134.0                9.45                13.2
# 3322               72.0                8.12                11.5
# 3323               56.0               10.22                13.6
# 3324               82.0                8.72                11.6
# 3325              109.0               10.95                 9.3
# 3326               92.0                8.05                14.9
# 3327              128.0                9.96                11.8
# 3328               83.0               12.56                 9.9
# 3329              123.0                8.61                 9.6
# 3330               91.0                8.64                14.1
# 3331              137.0                6.26                 5.0
# 3332               77.0               10.86                13.7
#
#       Total intl calls  Total intl charge  Customer service calls  Churn  \
# 3318                 4               3.13                     2.0  False
# 3319                 6               4.29                     3.0  False
# 3320                 4               2.62                     4.0   True
# 3321                 8               3.56                     3.0  False
# 3322                 2               3.11                     4.0   True
# 3323                 3               3.67                     5.0   True
# 3324                 4               3.13                     1.0  False
# 3325                 4               2.51                     2.0  False
# 3326                 7               4.02                     1.0  False
# 3327                 5               3.19                     2.0  False
# 3328                 6               2.67                     2.0  False
# 3329                 4               2.59                     3.0  False
# 3330                 6               3.81                     2.0  False
# 3331                10               1.35                     2.0  False
# 3332                 4               3.70                     0.0  False
#
#       New Column Churn Binary
# 3318         100            0
# 3319         100            0
# 3320         100            1
# 3321         100            0
# 3322         100            1
# 3323         100            1
# 3324         100            0
# 3325         100            0
# 3326         100            0
# 3327         100            0
# 3328         100            0
# 3329         100            0
# 3330         100            0
# 3331         100            0
# 3332         100            0
#
# [15 rows x 22 columns]

# %% [markdown]
# 2.2 Show Columns and Data Type

# %%
df.columns
# Out:
# Index(['State', 'Account length', 'Area code', 'International plan',
#        'Voice mail plan', 'Number vmail messages', 'Total day minutes',
#        'Total day calls', 'Total day charge', 'Total eve minutes',
#        'Total eve calls', 'Total eve charge', 'Total night minutes',
#        'Total night calls', 'Total night charge', 'Total intl minutes',
#        'Total intl calls', 'Total intl charge', 'Customer service calls',
#        'Churn', 'New Column', 'Churn Binary'],
#       dtype='object')

# %%
df.dtypes
# Out:
# State                      object
# Account length              int64
# Area code                   int64
# International plan         object
# Voice mail plan            object
# Number vmail messages       int64
# Total day minutes         float64
# Total day calls           float64
# Total day charge          float64
# Total eve minutes         float64
# Total eve calls           float64
# Total eve charge          float64
# Total night minutes       float64
# Total night calls         float64
# Total night charge        float64
# Total intl minutes        float64
# Total intl calls            int64
# Total intl charge         float64
# Customer service calls    float64
# Churn                      object
# New Column                  int64
# Churn Binary                int64
# dtype: object

# %% [markdown]
# 2.3 Summary Statistics

# %%
df.describe()
# Out:
#        Account length    Area code  Number vmail messages  Total day minutes  \
# count     3307.000000  3307.000000            3307.000000        3307.000000
# mean       101.072573   437.141820               8.061385         179.745116
# std         39.808520    42.345868              13.667145          54.492493
# min          1.000000   408.000000               0.000000           0.000000
# 25%         74.000000   408.000000               0.000000         143.600000
# 50%        101.000000   415.000000               0.000000         179.300000
# 75%        127.000000   510.000000              19.000000         216.500000
# max        243.000000   510.000000              51.000000         350.800000
#
#        Total day calls  Total day charge  Total eve minutes  Total eve calls  \
# count      3307.000000       3307.000000        3307.000000      3307.000000
# mean        100.446024         30.557212         200.946538       100.173571
# std          20.064620          9.263710          50.514273        19.929825
# min           0.000000          0.000000           0.000000         0.000000
# 25%          87.000000         24.410000         166.600000        87.000000
# 50%         101.000000         30.480000         201.300000       100.000000
# 75%         114.000000         36.805000         235.300000       114.000000
# max         165.000000         59.640000         363.700000       170.000000
#
#        Total eve charge  Total night minutes  Total night calls  \
# count       3307.000000          3307.000000        3307.000000
# mean          17.080668           200.972725         100.107046
# std            4.293716            50.541952          19.543413
# min            0.000000            23.200000          33.000000
# 25%           14.160000           167.100000          87.000000
# 50%           17.110000           201.300000         100.000000
# 75%           20.000000           235.400000         113.000000
# max           30.910000           395.000000         175.000000
#
#        Total night charge  Total intl minutes  Total intl calls  \
# count         3307.000000         3307.000000       3307.000000
# mean             9.043846           10.234593          4.471424
# std              2.274444            2.794218          2.450851
# min              1.040000            0.000000          0.000000
# 25%              7.520000            8.500000          3.000000
# 50%              9.060000           10.300000          4.000000
# 75%             10.590000           12.100000          6.000000
# max             17.770000           20.000000         20.000000
#
#        Total intl charge  Customer service calls  New Column  Churn Binary
# count        3307.000000             3307.000000      3307.0   3307.000000
# mean            2.763846                1.561234       100.0      0.145147
# std             0.754415                1.314486         0.0      0.352302
# min             0.000000                0.000000       100.0      0.000000
# 25%             2.300000                1.000000       100.0      0.000000
# 50%             2.780000                1.000000       100.0      0.000000
# 75%             3.270000                2.000000       100.0      0.000000
# max             5.400000                9.000000       100.0      1.000000

# %%
df.describe(include='object')
# Out:
#        State International plan Voice mail plan  Churn
# count   3307               3307            3307   3307
# unique    51                  2               2      2
# top       WV                 No              No  False
# freq     106               2985            2396   2827

# %% [markdown]
# 2.4 Filtering Columns

# %%
df.State
# Out:
# 0       KS
# 1       OH
# 2       NJ
# 3       OH
# 4       OK
#         ..
# 3328    AZ
# 3329    WV
# 3330    RI
# 3331    CT
# 3332    TN
# Name: State, Length: 3307, dtype: object

# %%
df['International plan']
# Out:
# 0        No
# 1        No
# 2        No
# 3       Yes
# 4       Yes
#        ...
# 3328     No
# 3329     No
# 3330     No
# 3331    Yes
# 3332     No
# Name: International plan, Length: 3307, dtype: object

# %%
df[['State', 'International plan']]
# Out:
#      State International plan
# 0       KS                 No
# 1       OH                 No
# 2       NJ                 No
# 3       OH                Yes
# 4       OK                Yes
# ...    ...                ...
# 3328    AZ                 No
# 3329    WV                 No
# 3330    RI                 No
# 3331    CT                Yes
# 3332    TN                 No
#
# [3307 rows x 2 columns]

# %%
df.State.unique()
# Out:
# array(['KS', 'OH', 'NJ', 'OK', 'AL', 'MO', 'LA', 'WV', 'IN', 'RI', 'SC',
#        'VA', 'NE', 'WY', 'MT', 'IL', 'GA', 'MD', 'AR', 'ID', 'WI', 'OR',
#        'MI', 'DE', 'IA', 'UT', 'CO', 'CA', 'MN', 'SD', 'NC', 'WA', 'TX',
#        'NM', 'NV', 'HI', 'DC', 'NY', 'VT', 'KY', 'ME', 'AZ', 'AK', 'MS',
#        'MA', 'FL', 'NH', 'TN', 'PA', 'CT', 'ND'], dtype=object)

# %%
df.Churn.unique()
# Out:
# array([False, True], dtype=object)

# %% [markdown]
# 2.5 Filtering Rows

# %%
df.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1            110.0
# 1                     26              161.6            123.0
# 2                      0              243.4            114.0
# 3                      0              299.4             71.0
# 4                      0              166.7            113.0
#
#    Total day charge  Total eve minutes  ...  Total night minutes  \
# 0             45.07              197.4  ...                244.7
# 1             27.47              195.5  ...                254.4
# 2             41.38              121.2  ...                162.6
# 3             50.90               61.9  ...                196.9
# 4             28.34              148.3  ...                186.9
#
#    Total night calls  Total night charge  Total intl minutes  \
# 0               91.0               11.01                10.0
# 1              103.0               11.45                13.7
# 2              104.0                7.32                12.2
# 3               89.0                8.86                 6.6
# 4              121.0                8.41                10.1
#
#    Total intl calls  Total intl charge  Customer service calls  Churn  \
# 0                 3               2.70                     1.0  False
# 1                 3               3.70                     1.0  False
# 2                 5               3.29                     0.0  False
# 3                 7               1.78                     2.0  False
# 4                 3               2.73                     3.0  False
#
#    New Column Churn Binary
# 0         100            0
# 1         100            0
# 2         100            0
# 3         100            0
# 4         100            0
#
# [5 rows x 22 columns]

# %%
df[df['International plan'] == 'No']
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 1       OH             107        415                 No             Yes
# 2       NJ             137        415                 No              No
# 8       LA             117        408                 No              No
# 10      IN              65        415                 No              No
# ...    ...             ...        ...                ...             ...
# 3327    SC              79        415                 No              No
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 0                        25              265.1            110.0
# 1                        26              161.6            123.0
# 2                         0              243.4            114.0
# 8                         0              184.5             97.0
# 10                        0              129.1            137.0
# ...                     ...                ...              ...
# 3327                      0              134.7             98.0
# 3328                     36              156.2             77.0
# 3329                      0              231.1             57.0
# 3330                      0              180.8            109.0
# 3332                     25              234.4            113.0
#
#       Total day charge  Total eve minutes  ...  Total night minutes  \
# 0                45.07              197.4  ...                244.7
# 1                27.47              195.5  ...                254.4
# 2                41.38              121.2  ...                162.6
# 8                31.37              351.6  ...                215.8
# 10               21.95              228.5  ...                208.8
# ...                ...                ...  ...                  ...
# 3327             22.90              189.7  ...                221.4
# 3328             26.55              215.5  ...                279.1
# 3329             39.29              153.4  ...                191.3
# 3330             30.74              288.8  ...                191.9
# 3332             39.85              265.9  ...                241.4
#
#       Total night calls  Total night charge  Total intl minutes  \
# 0                  91.0               11.01                10.0
# 1                 103.0               11.45                13.7
# 2                 104.0                7.32                12.2
# 8                  90.0                9.71                 8.7
# 10                111.0                9.40                12.7
# ...                 ...                 ...                 ...
# 3327              128.0                9.96                11.8
# 3328               83.0               12.56                 9.9
# 3329              123.0                8.61                 9.6
# 3330               91.0                8.64                14.1
# 3332               77.0               10.86                13.7
#
#       Total intl calls  Total intl charge  Customer service calls  Churn  \
# 0                    3               2.70                     1.0  False
# 1                    3               3.70                     1.0  False
# 2                    5               3.29                     0.0  False
# 8                    4               2.35                     1.0  False
# 10                   6               3.43                     4.0   True
# ...                ...                ...                     ...    ...
# 3327                 5               3.19                     2.0  False
# 3328                 6               2.67                     2.0  False
# 3329                 4               2.59                     3.0  False
# 3330                 6               3.81                     2.0  False
# 3332                 4               3.70                     0.0  False
#
#       New Column Churn Binary
# 0            100            0
# 1            100            0
# 2            100            0
# 8            100            0
# 10           100            1
# ...          ...          ...
# 3327         100            0
# 3328         100            0
# 3329         100            0
# 3330         100            0
# 3332         100            0
#
# [2985 rows x 22 columns]

# %%
df[(df['International plan'] == 'No') & (df['Churn'] == False)]
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 1       OH             107        415                 No             Yes
# 2       NJ             137        415                 No              No
# 8       LA             117        408                 No              No
# 11      RI              74        415                 No              No
# ...    ...             ...        ...                ...             ...
# 3327    SC              79        415                 No              No
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 0                        25              265.1            110.0
# 1                        26              161.6            123.0
# 2                         0              243.4            114.0
# 8                         0              184.5             97.0
# 11                        0              187.7            127.0
# ...                     ...                ...              ...
# 3327                      0              134.7             98.0
# 3328                     36              156.2             77.0
# 3329                      0              231.1             57.0
# 3330                      0              180.8            109.0
# 3332                     25              234.4            113.0
#
#       Total day charge  Total eve minutes  ...  Total night minutes  \
# 0                45.07              197.4  ...                244.7
# 1                27.47              195.5  ...                254.4
# 2                41.38              121.2  ...                162.6
# 8                31.37              351.6  ...                215.8
# 11               31.91              163.4  ...                196.0
# ...                ...                ...  ...                  ...
# 3327             22.90              189.7  ...                221.4
# 3328             26.55              215.5  ...                279.1
# 3329             39.29              153.4  ...                191.3
# 3330             30.74              288.8  ...                191.9
# 3332             39.85              265.9  ...                241.4
#
#       Total night calls  Total night charge  Total intl minutes  \
# 0                  91.0               11.01                10.0
# 1                 103.0               11.45                13.7
# 2                 104.0                7.32                12.2
# 8                  90.0                9.71                 8.7
# 11                 94.0                8.82                 9.1
# ...                 ...                 ...                 ...
# 3327              128.0                9.96                11.8
# 3328               83.0               12.56                 9.9
# 3329              123.0                8.61                 9.6
# 3330               91.0                8.64                14.1
# 3332               77.0               10.86                13.7
#
#       Total intl calls  Total intl charge  Customer service calls  Churn  \
# 0                    3               2.70                     1.0  False
# 1                    3               3.70                     1.0  False
# 2                    5               3.29                     0.0  False
# 8                    4               2.35                     1.0  False
# 11                   5               2.46                     0.0  False
# ...                ...                ...                     ...    ...
# 3327                 5               3.19                     2.0  False
# 3328                 6               2.67                     2.0  False
# 3329                 4               2.59                     3.0  False
# 3330                 6               3.81                     2.0  False
# 3332                 4               3.70                     0.0  False
#
#       New Column Churn Binary
# 0            100            0
# 1            100            0
# 2            100            0
# 8            100            0
# 11           100            0
# ...          ...          ...
# 3327         100            0
# 3328         100            0
# 3329         100            0
# 3330         100            0
# 3332         100            0
#
# [2642 rows x 22 columns]

# %%
df[(df['International plan'] == 'No') & (df['Churn'] == True)]
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 10      IN              65        415                 No              No
# 48      ID             119        415                 No              No
# 54      WY              87        415                 No              No
# 57      CO             121        408                 No             Yes
# 69      TX             150        510                 No              No
# ...    ...             ...        ...                ...             ...
# 3280    AR              76        408                 No              No
# 3287    KS             170        415                 No             Yes
# 3301    CA              84        415                 No              No
# 3322    MD              62        408                 No              No
# 3323    IN             117        415                 No              No
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 10                        0              129.1            137.0
# 48                        0              159.1            114.0
# 54                        0              151.0             83.0
# 57                       30              198.4            129.0
# 69                        0              178.9            101.0
# ...                     ...                ...              ...
# 3280                      0              107.3            140.0
# 3287                     42              199.5            119.0
# 3301                      0              280.0            113.0
# 3322                      0              321.1            105.0
# 3323                      0              118.4            126.0
#
#       Total day charge  Total eve minutes  ...  Total night minutes  \
# 10               21.95              228.5  ...                208.8
# 48               27.05              231.3  ...                143.2
# 54               25.67              219.7  ...                203.9
# 57               33.73               75.3  ...                181.2
# 69               30.41              169.1  ...                148.6
# ...                ...                ...  ...                  ...
# 3280             18.24              238.2  ...                271.8
# 3287             33.92              135.0  ...                184.6
# 3301             47.60              202.2  ...                156.8
# 3322             54.59              265.5  ...                180.5
# 3323             20.13              249.3  ...                227.0
#
#       Total night calls  Total night charge  Total intl minutes  \
# 10                111.0                9.40                12.7
# 48                 91.0                6.44                 8.8
# 54                127.0                9.18                 9.7
# 57                 77.0                8.15                 5.8
# 69                100.0                6.69                13.8
# ...                 ...                 ...                 ...
# 3280              116.0               12.23                10.0
# 3287               49.0                8.31                10.9
# 3301              103.0                7.06                10.4
# 3322               72.0                8.12                11.5
# 3323               56.0               10.22                13.6
#
#       Total intl calls  Total intl charge  Customer service calls  Churn  \
# 10                   6               3.43                     4.0   True
# 48                   3               2.38                     5.0   True
# 54                   3               2.62                     5.0   True
# 57                   3               1.57                     3.0   True
# 69                   3               3.73                     4.0   True
# ...                ...                ...                     ...    ...
# 3280                 3               2.70                     4.0   True
# 3287                 3               2.94                     4.0   True
# 3301                 4               2.81                     0.0   True
# 3322                 2               3.11                     4.0   True
# 3323                 3               3.67                     5.0   True
#
#       New Column Churn Binary
# 10           100            1
# 48           100            1
# 54           100            1
# 57           100            1
# 69           100            1
# ...          ...          ...
# 3280         100            1
# 3287         100            1
# 3301         100            1
# 3322         100            1
# 3323         100            1
#
# [343 rows x 22 columns]

# %% [markdown]
# 2.6 Indexing with iloc

# %%
df.iloc[14]
# Out:
# State                        WY
# Account length               57
# Area code                   408
# International plan           No
# Voice mail plan             Yes
# Number vmail messages        39
# Total day minutes         213.0
# Total day calls           115.0
# Total day charge          36.21
# Total eve minutes         191.1
# Total eve calls           112.0
# Total eve charge          16.24
# Total night minutes       182.7
# Total night calls         115.0
# Total night charge         8.22
# Total intl minutes          9.5
# Total intl calls              3
# Total intl charge          2.57
# Customer service calls      0.0
# Churn                     False
# New Column                  100
# Churn Binary                  0
# Name: 26, dtype: object

# %%
df.iloc[14, 0]
# Out:
# 'WY'

# %%
df.iloc[14, -1]
# Out:
# np.int64(0)

# %%
df.iloc[22:33]
# Out:
#    State  Account length  Area code International plan Voice mail plan  \
# 43    ID             160        415                 No              No
# 44    WI              64        510                 No              No
# 45    OR              59        408                 No             Yes
# 46    MI              65        415                 No              No
# 47    DE             142        408                 No              No
# 48    ID             119        415                 No              No
# 49    WY              97        415                 No             Yes
# 50    IA              52        408                 No              No
# 51    IN              60        408                 No              No
# 52    VA              10        408                 No              No
# 53    UT              96        415                 No              No
#
#     Number vmail messages  Total day minutes  Total day calls  \
# 43                      0               85.8             77.0
# 44                      0              154.0             67.0
# 45                     28              120.9             97.0
# 46                      0              211.3            120.0
# 47                      0              187.0            133.0
# 48                      0              159.1            114.0
# 49                     24              133.2            135.0
# 50                      0              191.9            108.0
# 51                      0              220.6             57.0
# 52                      0              186.1            112.0
# 53                      0              160.2            117.0
#
#     Total day charge  Total eve minutes  ...  Total night minutes  \
# 43             14.59              165.3  ...                178.5
# 44             26.18              225.8  ...                265.3
# 45             20.55              213.0  ...                163.1
# 46             35.92              162.6  ...                134.7
# 47             31.79              134.6  ...                242.2
# 48             27.05              231.3  ...                143.2
# 49             22.64              217.2  ...                 70.6
# 50             32.62              269.8  ...                236.8
# 51             37.50              211.1  ...                249.0
# 52             31.64              190.2  ...                282.8
# 53             27.23              267.5  ...                228.5
#
#     Total night calls  Total night charge  Total intl minutes  \
# 43               92.0                8.03                 9.2
# 44               86.0               11.94                 3.5
# 45              116.0                7.34                 8.5
# 46              118.0                6.06                13.2
# 47              127.0               10.90                 7.4
# 48               91.0                6.44                 8.8
# 49               79.0                3.18                11.0
# 50               87.0               10.66                 7.8
# 51              129.0               11.21                 6.8
# 52               57.0               12.73                11.4
# 53               68.0               10.28                 9.3
#
#     Total intl calls  Total intl charge  Customer service calls  Churn  \
# 43                 4               2.48                     3.0  False
# 44                 3               0.95                     1.0  False
# 45                 5               2.30                     2.0  False
# 46                 5               3.56                     3.0  False
# 47                 5               2.00                     2.0  False
# 48                 3               2.38                     5.0   True
# 49                 3               2.97                     1.0  False
# 50                 5               2.11                     3.0  False
# 51                 3               1.84                     1.0  False
# 52                 6               3.08                     2.0  False
# 53                 5               2.51                     2.0  False
#
#     New Column Churn Binary
# 43         100            0
# 44         100            0
# 45         100            0
# 46         100            0
# 47         100            0
# 48         100            1
# 49         100            0
# 50         100            0
# 51         100            0
# 52         100            0
# 53         100            0
#
# [11 rows x 22 columns]

# %% [markdown]
# 2.7 Indexing with loc

# %%
state = df.copy()
state.set_index('State', inplace=True)

# %%
state.head()
# Out:
#        Account length  Area code International plan Voice mail plan  \
# State
# KS                128        415                 No             Yes
# OH                107        415                 No             Yes
# NJ                137        415                 No              No
# OH                 84        408                Yes              No
# OK                 75        415                Yes              No
#
#        Number vmail messages  Total day minutes  Total day calls  \
# State
# KS                        25              265.1            110.0
# OH                        26              161.6            123.0
# NJ                         0              243.4            114.0
# OH                         0              299.4             71.0
# OK                         0              166.7            113.0
#
#        Total day charge  Total eve minutes  Total eve calls  ...  \
# State                                                        ...
# KS                45.07              197.4             99.0  ...
# OH                27.47              195.5            103.0  ...
# NJ                41.38              121.2            110.0  ...
# OH                50.90               61.9             88.0  ...
# OK                28.34              148.3            122.0  ...
#
#        Total night minutes  Total night calls  Total night charge  \
# State
# KS                   244.7               91.0               11.01
# OH                   254.4              103.0               11.45
# NJ                   162.6              104.0                7.32
# OH                   196.9               89.0                8.86
# OK                   186.9              121.0                8.41
#
#        Total intl minutes  Total intl calls  Total intl charge  \
# State
# KS                   10.0                 3               2.70
# OH                   13.7                 3               3.70
# NJ                   12.2                 5               3.29
# OH                    6.6                 7               1.78
# OK                   10.1                 3               2.73
#
#        Customer service calls  Churn New Column  Churn Binary
# State
# KS                        1.0  False        100             0
# OH                        1.0  False        100             0
# NJ                        0.0  False        100             0
# OH                        2.0  False        100             0
# OK                        3.0  False        100             0
#
# [5 rows x 21 columns]

# %%
state.loc['OH']
# Out:
#        Account length  Area code International plan Voice mail plan  \
# State
# OH                107        415                 No             Yes
# OH                 84        408                Yes              No
# OH                 65        408                 No              No
# OH                 83        415                 No              No
# OH                 63        415                Yes             Yes
# ...               ...        ...                ...             ...
# OH                160        415                 No              No
# OH                 88        408                 No              No
# OH                106        415                 No             Yes
# OH                 78        408                 No              No
# OH                 96        415                 No              No
#
#        Number vmail messages  Total day minutes  Total day calls  \
# State
# OH                        26              161.6            123.0
# OH                         0              299.4             71.0
# OH                         0              187.9            116.0
# OH                         0              337.4            120.0
# OH                        36              199.0            110.0
# ...                      ...                ...              ...
# OH                         0              206.3             66.0
# OH                         0              274.6            105.0
# OH                        30              220.1            105.0
# OH                         0              193.4             99.0
# OH                         0              106.6            128.0
#
#        Total day charge  Total eve minutes  Total eve calls  ...  \
# State                                                        ...
# OH                27.47              195.5            103.0  ...
# OH                50.90               61.9             88.0  ...
# OH                31.94              157.6            117.0  ...
# OH                57.36              227.4            116.0  ...
# OH                33.83              291.3            111.0  ...
# ...                 ...                ...              ...  ...
# OH                35.07              241.1            109.0  ...
# OH                46.68              161.1            121.0  ...
# OH                37.42              222.2            109.0  ...
# OH                32.88              116.9             88.0  ...
# OH                18.12              284.8             87.0  ...
#
#        Total night minutes  Total night calls  Total night charge  \
# State
# OH                   254.4              103.0               11.45
# OH                   196.9               89.0                8.86
# OH                   227.3               86.0               10.23
# OH                   153.9              114.0                6.93
# OH                   197.6               92.0                8.89
# ...                    ...                ...                 ...
# OH                   227.8              102.0               10.25
# OH                   194.4              123.0                8.75
# OH                   158.4               96.0                7.13
# OH                   243.3              109.0               10.95
# OH                   178.9               92.0                8.05
#
#        Total intl minutes  Total intl calls  Total intl charge  \
# State
# OH                   13.7                 3               3.70
# OH                    6.6                 7               1.78
# OH                    7.5                 6               2.03
# OH                   15.8                 7               4.27
# OH                   11.0                 6               2.97
# ...                   ...               ...                ...
# OH                   11.7                 6               3.16
# OH                    9.2                 4               2.48
# OH                   13.1                 8               3.54
# OH                    9.3                 4               2.51
# OH                   14.9                 7               4.02
#
#        Customer service calls  Churn New Column  Churn Binary
# State
# OH                        1.0  False        100             0
# OH                        2.0  False        100             0
# OH                        1.0  False        100             0
# OH                        0.0   True        100             1
# OH                        1.0  False        100             0
# ...                       ...    ...        ...           ...
# OH                        0.0  False        100             0
# OH                        2.0  False        100             0
# OH                        0.0  False        100             0
# OH                        2.0  False        100             0
# OH                        1.0  False        100             0
#
# [78 rows x 21 columns]

# %% [markdown]
# 3. UPDATE

# %% [markdown]
# 3.1 Dropping Rows

# %%
df.isnull().sum()
# Out:
# State                     0
# Account length            0
# Area code                 0
# International plan        0
# Voice mail plan           0
# Number vmail messages     0
# Total day minutes         0
# Total day calls           0
# Total day charge          0
# Total eve minutes         0
# Total eve calls           0
# Total eve charge          0
# Total night minutes       0
# Total night calls         0
# Total night charge        0
# Total intl minutes        0
# Total intl calls          0
# Total intl charge         0
# Customer service calls    0
# Churn                     0
# New Column                0
# Churn Binary              0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# State                     0
# Account length            0
# Area code                 0
# International plan        0
# Voice mail plan           0
# Number vmail messages     0
# Total day minutes         0
# Total day calls           0
# Total day charge          0
# Total eve minutes         0
# Total eve calls           0
# Total eve charge          0
# Total night minutes       0
# Total night calls         0
# Total night charge        0
# Total intl minutes        0
# Total intl calls          0
# Total intl charge         0
# Customer service calls    0
# Churn                     0
# New Column                0
# Churn Binary              0
# dtype: int64

# %% [markdown]
# 3.2 Dropping Columns

# %%
df.drop('Area code', axis=1)
# Out:
#      State  Account length International plan Voice mail plan  \
# 0       KS             128                 No             Yes
# 1       OH             107                 No             Yes
# 2       NJ             137                 No              No
# 3       OH              84                Yes              No
# 4       OK              75                Yes              No
# ...    ...             ...                ...             ...
# 3328    AZ             192                 No             Yes
# 3329    WV              68                 No              No
# 3330    RI              28                 No              No
# 3331    CT             184                Yes              No
# 3332    TN              74                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 0                        25              265.1            110.0
# 1                        26              161.6            123.0
# 2                         0              243.4            114.0
# 3                         0              299.4             71.0
# 4                         0              166.7            113.0
# ...                     ...                ...              ...
# 3328                     36              156.2             77.0
# 3329                      0              231.1             57.0
# 3330                      0              180.8            109.0
# 3331                      0              213.8            105.0
# 3332                     25              234.4            113.0
#
#       Total day charge  Total eve minutes  Total eve calls  ...  \
# 0                45.07              197.4             99.0  ...
# 1                27.47              195.5            103.0  ...
# 2                41.38              121.2            110.0  ...
# 3                50.90               61.9             88.0  ...
# 4                28.34              148.3            122.0  ...
# ...                ...                ...              ...  ...
# 3328             26.55              215.5            126.0  ...
# 3329             39.29              153.4             55.0  ...
# 3330             30.74              288.8             58.0  ...
# 3331             36.35              159.6             84.0  ...
# 3332             39.85              265.9             82.0  ...
#
#       Total night minutes  Total night calls  Total night charge  \
# 0                   244.7               91.0               11.01
# 1                   254.4              103.0               11.45
# 2                   162.6              104.0                7.32
# 3                   196.9               89.0                8.86
# 4                   186.9              121.0                8.41
# ...                   ...                ...                 ...
# 3328                279.1               83.0               12.56
# 3329                191.3              123.0                8.61
# 3330                191.9               91.0                8.64
# 3331                139.2              137.0                6.26
# 3332                241.4               77.0               10.86
#
#       Total intl minutes  Total intl calls  Total intl charge  \
# 0                   10.0                 3               2.70
# 1                   13.7                 3               3.70
# 2                   12.2                 5               3.29
# 3                    6.6                 7               1.78
# 4                   10.1                 3               2.73
# ...                  ...               ...                ...
# 3328                 9.9                 6               2.67
# 3329                 9.6                 4               2.59
# 3330                14.1                 6               3.81
# 3331                 5.0                10               1.35
# 3332                13.7                 4               3.70
#
#       Customer service calls  Churn New Column  Churn Binary
# 0                        1.0  False        100             0
# 1                        1.0  False        100             0
# 2                        0.0  False        100             0
# 3                        2.0  False        100             0
# 4                        3.0  False        100             0
# ...                      ...    ...        ...           ...
# 3328                     2.0  False        100             0
# 3329                     3.0  False        100             0
# 3330                     2.0  False        100             0
# 3331                     2.0  False        100             0
# 3332                     0.0  False        100             0
#
# [3307 rows x 21 columns]

# %% [markdown]
# 3.3 Creating Calculated Columns

# %%
df['New Column'] = df['Total night minutes'] + df['Total intl minutes']

# %%
df.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1            110.0
# 1                     26              161.6            123.0
# 2                      0              243.4            114.0
# 3                      0              299.4             71.0
# 4                      0              166.7            113.0
#
#    Total day charge  Total eve minutes  ...  Total night minutes  \
# 0             45.07              197.4  ...                244.7
# 1             27.47              195.5  ...                254.4
# 2             41.38              121.2  ...                162.6
# 3             50.90               61.9  ...                196.9
# 4             28.34              148.3  ...                186.9
#
#    Total night calls  Total night charge  Total intl minutes  \
# 0               91.0               11.01                10.0
# 1              103.0               11.45                13.7
# 2              104.0                7.32                12.2
# 3               89.0                8.86                 6.6
# 4              121.0                8.41                10.1
#
#    Total intl calls  Total intl charge  Customer service calls  Churn  \
# 0                 3               2.70                     1.0  False
# 1                 3               3.70                     1.0  False
# 2                 5               3.29                     0.0  False
# 3                 7               1.78                     2.0  False
# 4                 3               2.73                     3.0  False
#
#    New Column Churn Binary
# 0       254.7            0
# 1       268.1            0
# 2       174.8            0
# 3       203.5            0
# 4       197.0            0
#
# [5 rows x 22 columns]

# %% [markdown]
# 3.4 Updating an entire column

# %%
df['New Column'] = 100

# %%
df.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1            110.0
# 1                     26              161.6            123.0
# 2                      0              243.4            114.0
# 3                      0              299.4             71.0
# 4                      0              166.7            113.0
#
#    Total day charge  Total eve minutes  ...  Total night minutes  \
# 0             45.07              197.4  ...                244.7
# 1             27.47              195.5  ...                254.4
# 2             41.38              121.2  ...                162.6
# 3             50.90               61.9  ...                196.9
# 4             28.34              148.3  ...                186.9
#
#    Total night calls  Total night charge  Total intl minutes  \
# 0               91.0               11.01                10.0
# 1              103.0               11.45                13.7
# 2              104.0                7.32                12.2
# 3               89.0                8.86                 6.6
# 4              121.0                8.41                10.1
#
#    Total intl calls  Total intl charge  Customer service calls  Churn  \
# 0                 3               2.70                     1.0  False
# 1                 3               3.70                     1.0  False
# 2                 5               3.29                     0.0  False
# 3                 7               1.78                     2.0  False
# 4                 3               2.73                     3.0  False
#
#    New Column Churn Binary
# 0         100            0
# 1         100            0
# 2         100            0
# 3         100            0
# 4         100            0
#
# [5 rows x 22 columns]

# %% [markdown]
# 3.5 Updating a single value

# %%
df.iloc[0,-1] = 10

# %%
df.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1            110.0
# 1                     26              161.6            123.0
# 2                      0              243.4            114.0
# 3                      0              299.4             71.0
# 4                      0              166.7            113.0
#
#    Total day charge  Total eve minutes  ...  Total night minutes  \
# 0             45.07              197.4  ...                244.7
# 1             27.47              195.5  ...                254.4
# 2             41.38              121.2  ...                162.6
# 3             50.90               61.9  ...                196.9
# 4             28.34              148.3  ...                186.9
#
#    Total night calls  Total night charge  Total intl minutes  \
# 0               91.0               11.01                10.0
# 1              103.0               11.45                13.7
# 2              104.0                7.32                12.2
# 3               89.0                8.86                 6.6
# 4              121.0                8.41                10.1
#
#    Total intl calls  Total intl charge  Customer service calls  Churn  \
# 0                 3               2.70                     1.0  False
# 1                 3               3.70                     1.0  False
# 2                 5               3.29                     0.0  False
# 3                 7               1.78                     2.0  False
# 4                 3               2.73                     3.0  False
#
#    New Column Churn Binary
# 0         100           10
# 1         100            0
# 2         100            0
# 3         100            0
# 4         100            0
#
# [5 rows x 22 columns]

# %% [markdown]
# 3.6 Condition based updating using APPLY

# %%
df['Churn Binary'] = df['Churn'].apply(lambda x: 1 if x==True else 0)

# %%
df.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1            110.0
# 1                     26              161.6            123.0
# 2                      0              243.4            114.0
# 3                      0              299.4             71.0
# 4                      0              166.7            113.0
#
#    Total day charge  Total eve minutes  ...  Total night minutes  \
# 0             45.07              197.4  ...                244.7
# 1             27.47              195.5  ...                254.4
# 2             41.38              121.2  ...                162.6
# 3             50.90               61.9  ...                196.9
# 4             28.34              148.3  ...                186.9
#
#    Total night calls  Total night charge  Total intl minutes  \
# 0               91.0               11.01                10.0
# 1              103.0               11.45                13.7
# 2              104.0                7.32                12.2
# 3               89.0                8.86                 6.6
# 4              121.0                8.41                10.1
#
#    Total intl calls  Total intl charge  Customer service calls  Churn  \
# 0                 3               2.70                     1.0  False
# 1                 3               3.70                     1.0  False
# 2                 5               3.29                     0.0  False
# 3                 7               1.78                     2.0  False
# 4                 3               2.73                     3.0  False
#
#    New Column Churn Binary
# 0         100            0
# 1         100            0
# 2         100            0
# 3         100            0
# 4         100            0
#
# [5 rows x 22 columns]

# %%
df[df['Churn']==True].head()
# Out:
#    State  Account length  Area code International plan Voice mail plan  \
# 10    IN              65        415                 No              No
# 41    MD             135        408                Yes             Yes
# 48    ID             119        415                 No              No
# 54    WY              87        415                 No              No
# 57    CO             121        408                 No             Yes
#
#     Number vmail messages  Total day minutes  Total day calls  \
# 10                      0              129.1            137.0
# 41                     41              173.1             85.0
# 48                      0              159.1            114.0
# 54                      0              151.0             83.0
# 57                     30              198.4            129.0
#
#     Total day charge  Total eve minutes  ...  Total night minutes  \
# 10             21.95              228.5  ...                208.8
# 41             29.43              203.9  ...                122.2
# 48             27.05              231.3  ...                143.2
# 54             25.67              219.7  ...                203.9
# 57             33.73               75.3  ...                181.2
#
#     Total night calls  Total night charge  Total intl minutes  \
# 10              111.0                9.40                12.7
# 41               78.0                5.50                14.6
# 48               91.0                6.44                 8.8
# 54              127.0                9.18                 9.7
# 57               77.0                8.15                 5.8
#
#     Total intl calls  Total intl charge  Customer service calls  Churn  \
# 10                 6               3.43                     4.0   True
# 41                15               3.94                     0.0   True
# 48                 3               2.38                     5.0   True
# 54                 3               2.62                     5.0   True
# 57                 3               1.57                     3.0   True
#
#     New Column Churn Binary
# 10         100            1
# 41         100            1
# 48         100            1
# 54         100            1
# 57         100            1
#
# [5 rows x 22 columns]

# %% [markdown]
# 4 DELETE/OUTPUT

# %% [markdown]
# 4.1 Output to CSV

# %%
df.to_csv('output.csv')

# %% [markdown]
# 4.2 Output to JSON

# %%
#df.to_json()

#commented out to avoid writing JSON output in the notebook, taking up too much space

# %% [markdown]
# 4.3 Output to HTML

# %%
#df.to_html()

#commented out to avoid writing HTML output in the notebook, taking up too much space

# %% [markdown]
# 4.4 Delete a dataframe

# %%
#del df

#commented out to avoid deleting the dataframe in the notebook, which would make further operations impossible
